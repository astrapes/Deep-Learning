# %% [markdown]
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분ㅡ

# %% [markdown]
# ### Dog Image 1,111개, Cat Image 1111개 총 2,222개

# %%
import numpy as np
import tensorflow as tf
import os, cv2, random
import matplotlib.pyplot as plt
from glob import glob
from tensorflow import keras
from keras.preprocessing import image
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.linear_model import LogisticRegression
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
seed=2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='../dataset/cat_and_dog/train/'

# %%
## used for resize and in our model
ROW, COL=96, 96
dogs, cats=[],[]
y_dogs, y_cats=[],[]

# %%
# 1,111개 이미지
dog_path=os.path.join(path, 'dog.5*')
cat_path=os.path.join(path, 'cat.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog image
for dog_img in glob(dog_path):
    dog=cv2.imread(dog_img)
    dog=cv2.cvtColor(dog,cv2.COLOR_BGR2GRAY)
    dog=cv2.resize(dog, (ROW, COL))
    dog=image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our dog image
for cat_img in glob(cat_path):
    cat=cv2.imread(cat_img)
    cat=cv2.cvtColor(cat,cv2.COLOR_BGR2GRAY)
    cat=cv2.resize(cat, (ROW, COL))
    cat=image.img_to_array(cat)
    cats.append(cat)

# %%
classes=['dog','cat']

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1,5,i+1)
    img=image.array_to_img(random.choice(dogs))
    plt.imshow(img,cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1,5,i+1)
    img=image.array_to_img(random.choice(cats))
    plt.imshow(img,cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
dogs[:5]
# Out:
# [array([[[138.],
#          [210.],
#          [103.],
#          ...,
#          [ 93.],
#          [122.],
#          [ 77.]],
#
#         [[143.],
#          [ 87.],
#          [221.],
#          ...,
#          [ 68.],
#          [ 73.],
#          [ 96.]],
#
#         [[108.],
#          [193.],
#          [223.],
#          ...,
#          [ 96.],
#          [113.],
#          [104.]],
#
#         ...,
#
#         [[199.],
#          [200.],
#          [199.],
#          ...,
#          [ 93.],
#          [ 74.],
#          [ 94.]],
#
#         [[190.],
#          [195.],
#          [201.],
#          ...,
#          [ 94.],
#          [ 80.],
#          [106.]],
#
#         [[188.],
#          [192.],
#          [184.],
#          ...,
#          [ 93.],
#          [100.],
#          [108.]]], dtype=float32),
#  array([[[ 64.],
#          [ 71.],
#          [113.],
#          ...,
#          [191.],
#          [217.],
#          [177.]],
#
#         [[ 46.],
#          [ 52.],
#          [ 81.],
#          ...,
#          [195.],
#          [215.],
#          [158.]],
#
#         [[ 45.],
#          [ 38.],
#          [ 82.],
#          ...,
#          [192.],
#          [194.],
#          [126.]],
#
#         ...,
#
#         [[255.],
#          [255.],
#          [255.],
#          ...,
#          [253.],
#          [253.],
#          [253.]],
#
#         [[255.],
#          [255.],
#          [255.],
#          ...,
#          [252.],
#          [252.],
#          [252.]],
#
#         [[255.],
#          [255.],
#          [255.],
#          ...,
#          [244.],
#          [244.],
#          [244.]]], dtype=float32),
#  array([[[192.],
#          [172.],
#          [162.],
#          ...,
#          [216.],
#          [219.],
#          [211.]],
#
#         [[201.],
#          [202.],
#          [205.],
#          ...,
#          [198.],
#          [211.],
#          [214.]],
#
#         [[194.],
#          [191.],
#          [197.],
#          ...,
#          [180.],
#          [206.],
#          [196.]],
#
#         ...,
#
#         [[121.],
#          [127.],
#          [126.],
#          ...,
#          [128.],
#          [124.],
#          [121.]],
#
#         [[126.],
#          [145.],
#          [124.],
#          ...,
#          [121.],
#          [117.],
#          [149.]],
#
#         [[133.],
#          [120.],
#          [129.],
#          ...,
#          [124.],
#          [121.],
#          [114.]]], dtype=float32),
#  array([[[238.],
#          [240.],
#          [241.],
#          ...,
#          [ 89.],
#          [ 79.],
#          [ 91.]],
#
#         [[230.],
#          [237.],
#          [241.],
#          ...,
#          [107.],
#          [ 75.],
#          [ 79.]],
#
#         [[239.],
#          [238.],
#          [239.],
#          ...,
#          [ 93.],
#          [ 83.],
#          [ 87.]],
#
#         ...,
#
#         [[196.],
#          [233.],
#          [244.],
#          ...,
#          [ 25.],
#          [ 24.],
#          [ 26.]],
#
#         [[191.],
#          [194.],
#          [236.],
#          ...,
#          [ 27.],
#          [ 24.],
#          [ 24.]],
#
#         [[224.],
#          [229.],
#          [227.],
#          ...,
#          [ 26.],
#          [ 28.],
#          [ 23.]]], dtype=float32),
#  array([[[ 48.],
#          [ 85.],
#          [ 72.],
#          ...,
#          [160.],
#          [180.],
#          [174.]],
#
#         [[ 74.],
#          [ 56.],
#          [ 93.],
#          ...,
#          [176.],
#          [175.],
#          [179.]],
#
#         [[ 82.],
#          [ 74.],
#          [ 79.],
#          ...,
#          [170.],
#          [176.],
#          [171.]],
#
#         ...,
#
#         [[ 97.],
#          [ 94.],
#          [117.],
#          ...,
#          [ 58.],
#          [ 56.],
#          [ 55.]],
#
#         [[ 97.],
#          [ 89.],
#          [126.],
#          ...,
#          [ 58.],
#          [ 60.],
#          [ 61.]],
#
#         [[ 91.],
#          [ 86.],
#          [121.],
#          ...,
#          [ 60.],
#          [ 61.],
#          [ 62.]]], dtype=float32)]

# %%
## just change the labels for 0 and 1
y_dogs=[1 for item in enumerate(dogs)]
y_cats=[0 for item in enumerate(cats)]

# %%
y_dogs[:5]
# Out:
# [1, 1, 1, 1, 1]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
x_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
x_train.shape,y_train.shape
# Out:
# ((2222, 96, 96, 1), (2222,))

# %%
x_train.shape
# Out:
# (2222, 96, 96, 1)

# %%
## used for resize and in our model
ROW, COL=96, 96
dogs, cats=[],[]
y_dogs, y_cats=[],[]

# %%
# 611개 이미지
dog_path=os.path.join(path, 'dog.12*')
cat_path=os.path.join(path, 'cat.12*')
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog image
for dog_img in glob(dog_path):
    dog=cv2.imread(dog_img)
    dog=cv2.cvtColor(dog,cv2.COLOR_BGR2GRAY)
    dog=cv2.resize(dog, (ROW, COL))
    dog=image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our dog image
for cat_img in glob(cat_path):
    cat=cv2.imread(cat_img)
    cat=cv2.cvtColor(cat,cv2.COLOR_BGR2GRAY)
    cat=cv2.resize(cat, (ROW, COL))
    cat=image.img_to_array(cat)
    cats.append(cat)

# %%
classes=['dog','cat']

# %%
## just change the labels for 0 and 1
y_dogs=[1 for item in enumerate(dogs)]
y_cats=[0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
x_test = np.concatenate((dogs,cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               18874880
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 19,104,225
# Trainable params: 19,104,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn2-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
model.fit(x_train, y_train, batch_size=32, epochs=40, validation_split=0.2, shuffle=True,
          callbacks=[checkpointer])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.6713 - accuracy: 0.6145 - val_loss: 0.9616 - val_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.96160, saving model to model/dogs_vs_cats-cnn2-01-0.9616.hdf5
# Epoch 2/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.6579 - accuracy: 0.6252 - val_loss: 1.1042 - val_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 0.96160
# Epoch 3/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.6503 - accuracy: 0.6246 - val_loss: 0.8794 - val_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 0.96160 to 0.87937, saving model to model/dogs_vs_cats-cnn2-03-0.8794.hdf5
# Epoch 4/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.6260 - accuracy: 0.6427 - val_loss: 0.8675 - val_accuracy: 0.1596
#
# Epoch 00004: val_loss improved from 0.87937 to 0.86754, saving model to model/dogs_vs_cats-cnn2-04-0.8675.hdf5
# Epoch 5/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.5719 - accuracy: 0.7068 - val_loss: 0.6696 - val_accuracy: 0.6652
#
# Epoch 00005: val_loss improved from 0.86754 to 0.66961, saving model to model/dogs_vs_cats-cnn2-05-0.6696.hdf5
# Epoch 6/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.4963 - accuracy: 0.7614 - val_loss: 0.9083 - val_accuracy: 0.4404
#
# Epoch 00006: val_loss did not improve from 0.66961
# Epoch 7/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.3787 - accuracy: 0.8295 - val_loss: 0.8011 - val_accuracy: 0.6809
#
# Epoch 00007: val_loss did not improve from 0.66961
# Epoch 8/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.2394 - accuracy: 0.9088 - val_loss: 1.0567 - val_accuracy: 0.6202
#
# Epoch 00008: val_loss did not improve from 0.66961
# Epoch 9/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.1565 - accuracy: 0.9477 - val_loss: 1.5050 - val_accuracy: 0.6180
#
# Epoch 00009: val_loss did not improve from 0.66961
# Epoch 10/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.1227 - accuracy: 0.9550 - val_loss: 1.9881 - val_accuracy: 0.4989
#
# Epoch 00010: val_loss did not improve from 0.66961
# Epoch 11/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.0371 - accuracy: 0.9904 - val_loss: 3.0035 - val_accuracy: 0.5011
#
# Epoch 00011: val_loss did not improve from 0.66961
# Epoch 12/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.0359 - accuracy: 0.9887 - val_loss: 2.4769 - val_accuracy: 0.5618
#
# Epoch 00012: val_loss did not improve from 0.66961
# Epoch 13/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.0341 - accuracy: 0.9916 - val_loss: 4.5974 - val_accuracy: 0.4337
#
# Epoch 00013: val_loss did not improve from 0.66961
# Epoch 14/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.0222 - accuracy: 0.9916 - val_loss: 2.8749 - val_accuracy: 0.5798
#
# Epoch 00014: val_loss did not improve from 0.66961
# Epoch 15/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.0234 - accuracy: 0.9938 - val_loss: 3.3109 - val_accuracy: 0.5393
#
# Epoch 00015: val_loss did not improve from 0.66961
# Epoch 16/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.0225 - accuracy: 0.9949 - val_loss: 4.5475 - val_accuracy: 0.3888
#
# Epoch 00016: val_loss did not improve from 0.66961
# Epoch 17/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 2.8205 - val_accuracy: 0.5551
#
# Epoch 00017: val_loss did not improve from 0.66961
# Epoch 18/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 0.0066 - accuracy: 0.9989 - val_loss: 5.3907 - val_accuracy: 0.4180
#
# Epoch 00018: val_loss did not improve from 0.66961
# Epoch 19/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 6.9109e-04 - accuracy: 1.0000 - val_loss: 3.8133 - val_accuracy: 0.5865
#
# Epoch 00019: val_loss did not improve from 0.66961
# Epoch 20/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 3.5692e-04 - accuracy: 1.0000 - val_loss: 6.2236 - val_accuracy: 0.4404
#
# Epoch 00020: val_loss did not improve from 0.66961
# Epoch 21/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 1.1946e-04 - accuracy: 1.0000 - val_loss: 5.6477 - val_accuracy: 0.4809
#
# Epoch 00021: val_loss did not improve from 0.66961
# Epoch 22/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 3.4437e-05 - accuracy: 1.0000 - val_loss: 5.6959 - val_accuracy: 0.4876
#
# Epoch 00022: val_loss did not improve from 0.66961
# Epoch 23/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 3.8108e-05 - accuracy: 1.0000 - val_loss: 5.8140 - val_accuracy: 0.4876
#
# Epoch 00023: val_loss did not improve from 0.66961
# Epoch 24/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 7.0704e-05 - accuracy: 1.0000 - val_loss: 6.2634 - val_accuracy: 0.4629
#
# Epoch 00024: val_loss did not improve from 0.66961
# Epoch 25/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 3.4213e-05 - accuracy: 1.0000 - val_loss: 6.2172 - val_accuracy: 0.4742
#
# Epoch 00025: val_loss did not improve from 0.66961
# Epoch 26/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 3.1925e-05 - accuracy: 1.0000 - val_loss: 6.2087 - val_accuracy: 0.4787
#
# Epoch 00026: val_loss did not improve from 0.66961
# Epoch 27/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 7.7044e-04 - accuracy: 1.0000 - val_loss: 6.3845 - val_accuracy: 0.4517
#
# Epoch 00027: val_loss did not improve from 0.66961
# Epoch 28/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 1.0860e-04 - accuracy: 1.0000 - val_loss: 5.5063 - val_accuracy: 0.5303
#
# Epoch 00028: val_loss did not improve from 0.66961
# Epoch 29/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 7.4628e-05 - accuracy: 1.0000 - val_loss: 6.6743 - val_accuracy: 0.4787
#
# Epoch 00029: val_loss did not improve from 0.66961
# Epoch 30/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 6.1103e-05 - accuracy: 1.0000 - val_loss: 6.0938 - val_accuracy: 0.4989
#
# Epoch 00030: val_loss did not improve from 0.66961
# Epoch 31/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 2.1041e-05 - accuracy: 1.0000 - val_loss: 6.2008 - val_accuracy: 0.4989
#
# Epoch 00031: val_loss did not improve from 0.66961
# Epoch 32/40
# 1777/1777 [==============================] - 36s 20ms/step - loss: 4.4668e-05 - accuracy: 1.0000 - val_loss: 5.3431 - val_accuracy: 0.5618
#
# Epoch 00032: val_loss did not improve from 0.66961
# Epoch 33/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 2.5769e-05 - accuracy: 1.0000 - val_loss: 5.7863 - val_accuracy: 0.5483
#
# Epoch 00033: val_loss did not improve from 0.66961
# Epoch 34/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 1.1805e-05 - accuracy: 1.0000 - val_loss: 5.9369 - val_accuracy: 0.5416
#
# Epoch 00034: val_loss did not improve from 0.66961
# Epoch 35/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 8.7545e-05 - accuracy: 1.0000 - val_loss: 5.7025 - val_accuracy: 0.5573
#
# Epoch 00035: val_loss did not improve from 0.66961
# Epoch 36/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.0321 - accuracy: 0.9899 - val_loss: 2.5615 - val_accuracy: 0.6135
#
# Epoch 00036: val_loss did not improve from 0.66961
# Epoch 37/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.0505 - accuracy: 0.9831 - val_loss: 3.3347 - val_accuracy: 0.4854
#
# Epoch 00037: val_loss did not improve from 0.66961
# Epoch 38/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.0507 - accuracy: 0.9842 - val_loss: 3.6587 - val_accuracy: 0.4742
#
# Epoch 00038: val_loss did not improve from 0.66961
# Epoch 39/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.0294 - accuracy: 0.9916 - val_loss: 3.0277 - val_accuracy: 0.5191
#
# Epoch 00039: val_loss did not improve from 0.66961
# Epoch 40/40
# 1777/1777 [==============================] - 35s 20ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 2.4953 - val_accuracy: 0.5618
#
# Epoch 00040: val_loss did not improve from 0.66961

# %%
del model

# %%
model = load_model('model/dogs_vs_cats-cnn2-05-0.6696.hdf5')
scores = model.evaluate(x_test, y_test, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# MODEL ACCURACY: 0.65303
